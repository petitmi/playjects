# %%
from passage_analysis import PassageAnalize
p = PassageAnalize("html.txt")
# Out:
# 2023-09-28 16:25:49.066765: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
word_cloud = p.wordcloud()

# %%
# For the part-of-speech categories, the univerisal features refer to: https://universaldependencies.org/u/pos/
nouns = p.text_analysis('NOUN')
verbs = p.text_analysis('VERB')

# %%
extraction = p.openai_analysis(api_key= '{Your openai-api-key}', keyword = 'Hannah Arendt')
print(extraction)
# Out:
# Facts:
#
# - Autoworkers in America are demanding a 32-hour workweek instead of the standard 40-hour workweek.
# - A shorter workweek is believed to be better for the health, well-being, and productivity of workers.
# - A reduction in work hours has been experimented with in other countries, such as Sweden, and has resulted in happier and healthier workers and positive outcomes for employers.
# - The United Auto Workers (UAW) can set an example for other workers through legislation.
# - President Biden supports the UAW and could also support a shift to a 32-hour workweek for all hourly workers.
# - The 40-hour workweek is relatively new, only becoming established in the 1940s.
# - There is a shift in societal priorities, with more emphasis on health and leisure time outside of work.
# - John Maynard Keynes predicted a significant reduction in working hours due to technological progress.
# ...
